# %%
from datetime import datetime
import numpy as np
import pandas as pd
import tensorflow as tf
from dateutil.relativedelta import relativedelta
import alpaca_trade_api as alp

with open('paper_api_keys.txt') as api_file:
    api_keys = api_file.read().replace('\n', '').split(',')
    alpaca_api = {a.split('=')[0]: a.split('=')[1] for a in api_keys}
    
api = alp.REST(key_id=alpaca_api['APCA_API_KEY_ID'], secret_key = alpaca_api['APCA_API_SECRET_KEY'], base_url=alpaca_api['APCA_API_BASE_URL'])

from Functions import *

start_date = '2020-01-01'
end_date = datetime.now()

buying_power = 100_000
max_per_trade = .01

#Get Alpaca APIs

### Get portfolio
###
#portfolio = pd.DataFrame([{'Symbol': p.symbol, 'Quantity': float(p.qty), 'Value': float(p.market_value)} for p in api.list_positions()])

portfolio = pd.DataFrame(columns = ['Symbol', 'Quantity', 'Value'])
portfolio['Symbol'] = portfolio['Symbol'].astype(str)
portfolio['Quantity'] = portfolio['Quantity'].astype(float)
portfolio['Value'] = portfolio['Value'].astype(float)

### Define One Day of trading behavior, should take in a date, and output the actions that will be taken

def TradingDay(current_day, portfolio, buying_power, api, epochs):
    ###Get stocks of Interest
    soi = IdentifyStocksOfInterest()
    ###combine with symbols from portfolio
    stocks_to_predict = list(set(portfolio['Symbol'].tolist() + soi))

    ### Make predictions
    preds = []
    current_prices = dict([])
    for symbol in stocks_to_predict:
        print('Working on: ' + symbol)

        data = GetHistoricalData(symbol, stocks_to_predict, up_until = current_day, api = api)

        if data is None:
            print('Skipping ' + symbol + ', insufficient data.')
            continue

        preds.append(Predict7DayHigh(symbol, data, epochs))
        current_prices[symbol] = data.iloc[-1][symbol]
    preds = dict(preds)
    predicted_stocks = list(preds.keys())

    ### Determine which to buy and which to sell
    orders = dict([])
    for symbol in predicted_stocks:
        
        if preds[symbol] > 0:
            side = 'buy'
            quantity = (buying_power * max_per_trade) // current_prices[symbol]

        elif (preds[symbol] < 0) and (symbol in portfolio['Symbol']):
            side = 'sell'
            quantity = portfolio[portfolio['Symbol']==symbol]['Quantity'].astype(int)[0]
        
        else:
            continue

        orders[symbol] = {'Side': side, 'Quantity': quantity}
    
    return orders

def Execution(day_of_order, orders, portfolio, buying_power):

    assert isinstance(day_of_order, pd.Timestamp)

    ###First, ensure your dates are valid
    calendar = api.get_calendar(start = day_of_order, end = day_of_order + relativedelta(days = 5))

    assert calendar[0].date == day_of_order

    ### Now determine which day these trades will be placed
    day_of_execution = calendar[1].date

    next_day_prices = api.get_barset(symbols = orders.keys(), timeframe = 'day', start = day_of_execution, limit = 1)
    next_day_prices = {symbol: next_day_prices[symbol][0].o for symbol in next_day_prices}

    for symbol in orders.keys():

        quantity = orders[symbol]['Quantity']
        price = next_day_prices[symbol]
        cost = quantity * next_day_prices[symbol]

        if symbol in portfolio['Symbol']:
            if orders[symbol][side] == 'buy':
                print('Trying to buy {} shares of {} at {} per share for a total cost of {}'.format(quantity, symbol, np.round(price, 5), np.round(cost,5)))
                if cost > buying_power:
                    print('Did not buy, total cost is {} and we only have {}'.format(cost, buying_power))
                    continue
                buying_power -= cost
                portfolio.loc[portfolio['Symbol']==symbol, 'Quantity'] += quantity
                portfolio.loc[portfolio['Symbol']==symbol, 'Value'] = portfolio.loc[portfolio['Symbol']==symbol, 'Quantity'] * price
                print('Successfully bought {} shares of {} at {} per share for a total cost of {}'.format(quantity, symbol, np.round(price, 5), np.round(cost,5)))
                print('New buying power: ' + str(buying_power))
            elif orders[symbol][side] == 'sell':
                print('Selling {} shares of {} at {} per share for a total sale of {}.'.format(quantity, symbol, np.round(price,5), np.round(cost,5)))
                buying_power += cost
                portfolio = portfolio[portfolio['Symbol'] != symbol]
                print('New buying power: ' + str(buying_power))
        else:
            print('Trying to buy {} shares of {} at {} per share for a total cost of {}'.format(quantity, symbol, np.round(price, 5), np.round(cost,5)))
            if cost > buying_power:
                print('Did not buy, total cost is {} and we only have {}'.format(cost, buying_power))
                continue
            buying_power -= cost
            portfolio = portfolio.append(pd.DataFrame([{'Symbol': symbol, 'Quantity': quantity, 'Value': quantity * cost}]))
            print('Successfully bought {} shares of {} at {} per share for a total cost of {}'.format(quantity, symbol, np.round(price, 5), np.round(cost,5)))
            print('New buying power: ' + str(buying_power))

    return portfolio, buying_power

# %%
day = datetime.now()

# %%
ok = api.polygon.historic_agg_v2(symbol = 'AAPL', multiplier=1, timespan = 'day', _from='2015-09-12', to='2020-10-02')

# %%
def GetHistoricalData(symbols, api, end, start = None, open_or_close = 'open'):
    ###For now, we will explicitly say what the relevant stocks are,
    ###but in future this should be automated
    symbols_to_pull = np.unique(symbols)
        
    if isinstance(end, str):
        end = pd.to_datetime(end)
    if end is None:
        end = datetime.now()
    
    ### We will use 5 years of historical daily data, meaning we need ~ 1,265 trading days of data,
    n_days = 1265
    if start == None:
        start = end - relativedelta(days = n_days)
        
    all_quotes = []
    for sym in symbols_to_pull:
        quotes = api.polygon.historic_agg_v2(symbol = sym, multiplier = 1, timespan = 'day', _from = start, to = end).df
        quotes = quotes[[open_or_close]]
        quotes.rename(columns={open_or_close: sym}, inplace = True)
        all_quotes.append(quotes)
    data = pd.concat(all_quotes, axis = 1)
        
    bad_cols = data.columns[data.isna().sum() > 0]
    if len(bad_cols) > 0:
        data = data.drop(bad_cols, axis = 1)
        print('Skipping {}, had missing values for the period.'.format(list(bad_cols)))
        
        return data

# %%
day_of_order = pd.to_datetime('2020-05-01')

if not isinstance(day_of_order, pd.Timestamp):
    day_of_order = pd.Timestamp(day_of_order, tz = 'America/New_York')

###First, ensure your dates are valid
calendar = api.get_calendar(start = day_of_order, end = day_of_order + relativedelta(days = 5))

assert calendar[0].date == day_of_order

### Now determine which day these trades will be placed
day_of_execution = calendar[1].date
print(day_of_execution)

next_day_prices = dict(GetDayQuotes(["AAPL", 'FIT'], api,  pd.Timestamp(day_of_execution, tz = 'America/New_York'), 'open'))
print(next_day_prices)
# Out:
# 2020-05-04 00:00:00
# {'AAPL': timestamp
# 2020-05-04 00:00:00-04:00    72.2925
# Name: AAPL, dtype: float64, 'FIT': timestamp
# 2020-05-04 00:00:00-04:00    6.81
# Name: FIT, dtype: float64}

# %%
def GetDayQuotes(symbols, api, date, open_or_close = 'open'):
    
    if isinstance(date, str):
        date = pd.to_datetime(end)
    if date is None:
        date = datetime.now()
        
    all_quotes = []
    for sym in symbols:
        quotes = api.polygon.historic_agg_v2(symbol = sym, multiplier = 1, timespan = 'day', _from = date, to = date).df
        quotes = quotes[[open_or_close]]
        quotes.rename(columns={open_or_close: sym}, inplace = True)
        all_quotes.append(quotes)
    data = pd.concat(all_quotes, axis = 1).head(1)
    bad_cols = data.columns[data.isna().sum() > 0]
    if len(bad_cols) > 0:
        data = data.drop(bad_cols, axis = 1)
        print('Skipping {}, had missing values for the period.'.format(list(bad_cols)))
    return dict(data.iloc[0])
# Out:
# {'AAPL': timestamp
# 2020-05-04 00:00:00-04:00    72.2925
# Name: AAPL, dtype: float64, 'FIT': timestamp
# 2020-05-04 00:00:00-04:00    6.81
# Name: FIT, dtype: float64}

# %%
GetLongReturns(['SPY'], api, pd.to_datetime('2019-11-01'), pd.to_datetime('2020-11-01'))
# Out:
# Top Fund: SPY
# Top Fund Return: 1.082906991997901
# Top 5 Funds: ['SPY']
# Top 5 Fund Return: 1.082906991997901
# Overall weighted Return: 1.082906991997901
#       Start    End    Return  ReturnRank
# SPY  304.92  330.2  1.082907         1.0

# %%
pd.DataFrame([{'A': 2, 'B': 4}]) * 2
# Out:
#    A  B
# 0  4  8

# %%
import tensorflow as tf

# %%
current_day = pd.to_datetime('2020-11-01')
###Get stocks of Interest
soi = IdentifyStocksOfInterest()
###combine with symbols from portfolio
stocks_to_predict = list(set(portfolio['Symbol'].tolist() + soi))
epochs = 5
### Make predictions
preds = []
current_prices = dict([])

### For now we are using same data for all of them, but in future data grab
### should be inside for loop

data = GetHistoricalData(stocks_to_predict, end = current_day, api = api)

stocks_to_predict = [col for col in data if col in stocks_to_predict]

for symbol in stocks_to_predict:
    preds.append(Predict7DayHigh(symbol, data, epochs))
    current_prices[symbol] = data.iloc[-1][symbol]
preds = dict(preds)
# Out:
# Skipping ['MRNA'], had missing values for the period.
# WARNING:tensorflow:Layer feed_back is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer feed_back_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer feed_back_2 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer feed_back_3 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:Layer feed_back_4 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe3ec570790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Layer feed_back_5 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe3ea1efaf0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Layer feed_back_6 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe3ec5ad940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Layer feed_back_7 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because its dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe3ec5ade50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
# Out:
# {'AAPL': -0.0657152853391731,
#  'AMD': 0.12877959523654206,
#  'BA': -0.14831663220920283,
#  'FIT': -1.7619703678374596,
#  'GPRO': 1.0103357908053276,
#  'MSFT': 0.0004303977957635827,
#  'PLUG': 1.2414764225213235,
#  'SNAP': -0.877734141245751}

# %%
preds
# Out:
# {'AAPL': -0.071478516,
#  'AMD': 0.09619836,
#  'BA': -0.22039852,
#  'FIT': -0.12421891,
#  'GPRO': 0.059104644,
#  'MSFT': 0.00087082386,
#  'PLUG': 0.1920564,
#  'SNAP': -0.35802776}

# %%
current_prices
# Out:
# {'AAPL': 108.77,
#  'AMD': 74.7,
#  'BA': 148.6,
#  'FIT': 7.05,
#  'GPRO': 5.85,
#  'MSFT': 202.33,
#  'PLUG': 15.47,
#  'SNAP': 40.79}

# %%
top_fund_return
# Out:
# 1.4732649203348636

# %%
# Out:
#                               AAPL   FIT
# timestamp
# 2019-12-26 00:00:00-05:00  72.4775  6.64
# 2019-12-27 00:00:00-05:00  72.4500  6.48
# 2019-12-30 00:00:00-05:00  72.8800  6.44
# 2019-12-31 00:00:00-05:00  73.4125  6.57
# 2020-01-02 00:00:00-05:00  75.0875  6.46

# %%
soi
# Out:
# [{'ask_price': '408.500000',
#   'ask_size': 2,
#   'bid_price': '405.200000',
#   'bid_size': 100,
#   'last_trade_price': '408.500000',
#   'last_extended_hours_trade_price': '408.210000',
#   'previous_close': '411.760000',
#   'adjusted_previous_close': '411.760000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'TSLA',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/e39ed23a-7bd1-4587-b060-71988d9ef483/'},
#  {'ask_price': '9.300000',
#   'ask_size': 200,
#   'bid_price': '6.150000',
#   'bid_size': 20,
#   'last_trade_price': '9.250000',
#   'last_extended_hours_trade_price': '9.270000',
#   'previous_close': '8.760000',
#   'adjusted_previous_close': '8.760000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'GE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/39ff611b-84e7-425b-bfb8-6fe2a983fcf3/'},
#  {'ask_price': '24.000000',
#   'ask_size': 20,
#   'bid_price': '23.050000',
#   'bid_size': 25,
#   'last_trade_price': '23.430000',
#   'last_extended_hours_trade_price': '23.570000',
#   'previous_close': '23.450000',
#   'adjusted_previous_close': '23.450000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'PLUG',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/ef99a2c4-adb2-4163-a2df-2d5722cc75b7/'},
#  {'ask_price': '5.100000',
#   'ask_size': 200,
#   'bid_price': '4.150000',
#   'bid_size': 2500,
#   'last_trade_price': '5.060000',
#   'last_extended_hours_trade_price': '5.030000',
#   'previous_close': '4.820000',
#   'adjusted_previous_close': '4.820000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'MRO',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/ab4f79fc-f84a-4f7b-8132-4f3e5fb38075/'},
#  {'ask_price': '36.500000',
#   'ask_size': 70,
#   'bid_price': '35.480000',
#   'bid_size': 2,
#   'last_trade_price': '36.080000',
#   'last_extended_hours_trade_price': '36.050000',
#   'previous_close': '35.230000',
#   'adjusted_previous_close': '35.230000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'XOM',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/9133b38b-4917-4b5a-8eab-c029d60f9912/'},
#  {'ask_price': '3.000000',
#   'ask_size': 6,
#   'bid_price': '2.750000',
#   'bid_size': 100,
#   'last_trade_price': '2.850000',
#   'last_extended_hours_trade_price': '2.870000',
#   'previous_close': '2.560000',
#   'adjusted_previous_close': '2.560000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'FCEL',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/4cc6e36f-e12a-4165-8267-012029c05053/'},
#  {'ask_price': '1.280000',
#   'ask_size': 200,
#   'bid_price': '1.150000',
#   'bid_size': 90,
#   'last_trade_price': '1.280000',
#   'last_extended_hours_trade_price': '1.250000',
#   'previous_close': '1.190000',
#   'adjusted_previous_close': '1.190000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'KOS',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/13ceb031-2023-461b-8d21-55719292549f/'},
#  {'ask_price': '5.450000',
#   'ask_size': 83,
#   'bid_price': '5.190000',
#   'bid_size': 200,
#   'last_trade_price': '5.360000',
#   'last_extended_hours_trade_price': '5.380000',
#   'previous_close': '5.300000',
#   'adjusted_previous_close': '5.300000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'ET',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/ddca4d36-b75e-4f88-8249-73cb1263dcbc/'},
#  {'ask_price': '22.220000',
#   'ask_size': 50,
#   'bid_price': '15.430000',
#   'bid_size': 40,
#   'last_trade_price': '18.800000',
#   'last_extended_hours_trade_price': '18.820000',
#   'previous_close': '18.280000',
#   'adjusted_previous_close': '18.280000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'BP',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/fb5c5151-e89b-4e9f-82ad-a51178c18e75/'},
#  {'ask_price': '15.990000',
#   'ask_size': 500,
#   'bid_price': '14.240000',
#   'bid_size': 75,
#   'last_trade_price': '14.330000',
#   'last_extended_hours_trade_price': '14.240000',
#   'previous_close': '13.920000',
#   'adjusted_previous_close': '13.920000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'HAL',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/38dc15e8-071c-4544-88b3-f633f0a69a4f/'},
#  {'ask_price': '12.000000',
#   'ask_size': 171,
#   'bid_price': '10.800000',
#   'bid_size': 230,
#   'last_trade_price': '11.800000',
#   'last_extended_hours_trade_price': '11.800000',
#   'previous_close': '11.310000',
#   'adjusted_previous_close': '11.310000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'OXY',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/35739e4a-7c80-495e-b5b8-55b281a11c30/'},
#  {'ask_price': '0.123500',
#   'ask_size': 87050,
#   'bid_price': '0.117000',
#   'bid_size': 5500,
#   'last_trade_price': '0.119900',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '0.123000',
#   'adjusted_previous_close': '0.123000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'OASPQ',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:59:03Z',
#   'instrument': 'https://api.robinhood.com/instruments/721c59ff-4c8f-41de-80ac-cdb625b2f22e/'},
#  {'ask_price': '56.570000',
#   'ask_size': 40,
#   'bid_price': '55.000000',
#   'bid_size': 1,
#   'last_trade_price': '55.400000',
#   'last_extended_hours_trade_price': '55.000000',
#   'previous_close': '53.380000',
#   'adjusted_previous_close': '53.380000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'RUN',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/a144bc4c-ebe0-4a0e-a048-e6536e0fbe8c/'},
#  {'ask_price': '41.100000',
#   'ask_size': 2700,
#   'bid_price': '0.693000',
#   'bid_size': 100,
#   'last_trade_price': '0.712100',
#   'last_extended_hours_trade_price': '0.720000',
#   'previous_close': '0.727000',
#   'adjusted_previous_close': '0.727000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'CEI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/bc04f71b-e031-4d38-adee-071106edece5/'},
#  {'ask_price': '85.260000',
#   'ask_size': 400,
#   'bid_price': '60.630000',
#   'bid_size': 10,
#   'last_trade_price': '83.030000',
#   'last_extended_hours_trade_price': '83.050000',
#   'previous_close': '80.670000',
#   'adjusted_previous_close': '80.670000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'CVX',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/7a6a30e2-cf4d-40dd-8baa-0cea48de85e4/'},
#  {'ask_price': '13.480000',
#   'ask_size': 6,
#   'bid_price': '3.850000',
#   'bid_size': 1000,
#   'last_trade_price': '11.400000',
#   'last_extended_hours_trade_price': '11.450000',
#   'previous_close': '11.100000',
#   'adjusted_previous_close': '11.100000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'PCG',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/f87d7cd7-a842-47cc-9b32-c607d96e7dfb/'},
#  {'ask_price': '123.000000',
#   'ask_size': 30,
#   'bid_price': '115.250000',
#   'bid_size': 20,
#   'last_trade_price': '116.590000',
#   'last_extended_hours_trade_price': '116.590000',
#   'previous_close': '117.210000',
#   'adjusted_previous_close': '117.210000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'ENPH',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/69cbc174-ead1-49a9-9c72-a8f015de474f/'},
#  {'ask_price': '22.000000',
#   'ask_size': 65,
#   'bid_price': '21.550000',
#   'bid_size': 3,
#   'last_trade_price': '21.700000',
#   'last_extended_hours_trade_price': '21.950000',
#   'previous_close': '21.600000',
#   'adjusted_previous_close': '21.600000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'ICLN',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/d9fc986d-df19-401b-bc76-dbd1cc6bb272/'},
#  {'ask_price': '1.600000',
#   'ask_size': 500,
#   'bid_price': '0.960000',
#   'bid_size': 100,
#   'last_trade_price': '1.010000',
#   'last_extended_hours_trade_price': '0.980000',
#   'previous_close': '0.900000',
#   'adjusted_previous_close': '0.900000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'TELL',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/83ee8f00-1e3e-4ba6-ba2b-6f3264ae0549/'},
#  {'ask_price': '31.480000',
#   'ask_size': 200,
#   'bid_price': '21.000000',
#   'bid_size': 100,
#   'last_trade_price': '31.210000',
#   'last_extended_hours_trade_price': '31.210000',
#   'previous_close': '30.630000',
#   'adjusted_previous_close': '30.630000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'RDS.A',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/af3b4d28-9aa1-4ad0-be9f-9c43704d1fa7/'},
#  {'ask_price': '19.300000',
#   'ask_size': 200,
#   'bid_price': '18.800000',
#   'bid_size': 100,
#   'last_trade_price': '18.985000',
#   'last_extended_hours_trade_price': '19.000000',
#   'previous_close': '18.730000',
#   'adjusted_previous_close': '18.730000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'SPWR',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/426bce10-aa0f-400f-ba01-d5ed30717d37/'},
#  {'ask_price': '341755.000000',
#   'ask_size': 3,
#   'bid_price': '341160.000000',
#   'bid_size': 2,
#   'last_trade_price': '341754.000000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '336811.000000',
#   'adjusted_previous_close': '336811.000000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'BRK.A',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/28356967-fa97-4e30-9b0b-2bc0cc975e95/'},
#  {'ask_price': '10.450000',
#   'ask_size': 10,
#   'bid_price': '10.100000',
#   'bid_size': 500,
#   'last_trade_price': '10.320000',
#   'last_extended_hours_trade_price': '10.300000',
#   'previous_close': '9.700000',
#   'adjusted_previous_close': '9.700000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'APA',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/8d286b84-0c1c-41e6-82c4-7818157d636b/'},
#  {'ask_price': '37.580000',
#   'ask_size': 130,
#   'bid_price': '35.330000',
#   'bid_size': 30,
#   'last_trade_price': '37.560000',
#   'last_extended_hours_trade_price': '37.560000',
#   'previous_close': '34.700000',
#   'adjusted_previous_close': '34.700000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'MPC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/b76a1f83-0926-4160-8f80-d2c574400d2f/'},
#  {'ask_price': '3.960000',
#   'ask_size': 20,
#   'bid_price': '2.800000',
#   'bid_size': 500,
#   'last_trade_price': '2.980000',
#   'last_extended_hours_trade_price': '2.980000',
#   'previous_close': '2.850000',
#   'adjusted_previous_close': '2.850000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'HLX',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/f60fa870-74a5-4d0b-b3e1-872c43ce63c7/'},
#  {'ask_price': '6.190000',
#   'ask_size': 2,
#   'bid_price': '4.000000',
#   'bid_size': 4,
#   'last_trade_price': '6.060000',
#   'last_extended_hours_trade_price': '6.060000',
#   'previous_close': '5.720000',
#   'adjusted_previous_close': '5.720000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'WPX',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/a7e8f920-6986-4336-83d3-84f94f0bdb7a/'},
#  {'ask_price': '34.000000',
#   'ask_size': 100,
#   'bid_price': '29.000000',
#   'bid_size': 150,
#   'last_trade_price': '33.600000',
#   'last_extended_hours_trade_price': '33.687500',
#   'previous_close': '31.660000',
#   'adjusted_previous_close': '31.660000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'FANG',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/00815789-becf-4d44-8733-032d602a33d8/'},
#  {'ask_price': '79.530000',
#   'ask_size': 1,
#   'bid_price': '72.790000',
#   'bid_size': 100,
#   'last_trade_price': '77.190000',
#   'last_extended_hours_trade_price': '77.190000',
#   'previous_close': '76.670000',
#   'adjusted_previous_close': '76.670000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'NEE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/68bae46a-c0a5-4cda-86a9-1d2460b0b7d3/'},
#  {'ask_price': '1.010000',
#   'ask_size': 55,
#   'bid_price': '0.980000',
#   'bid_size': 200,
#   'last_trade_price': '0.998800',
#   'last_extended_hours_trade_price': '0.981000',
#   'previous_close': '0.976300',
#   'adjusted_previous_close': '0.976300',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'GEVO',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/2e153a47-7b8a-4ebc-a37b-a3848288166b/'},
#  {'ask_price': '29.400000',
#   'ask_size': 20,
#   'bid_price': '25.950000',
#   'bid_size': 15,
#   'last_trade_price': '29.390000',
#   'last_extended_hours_trade_price': '29.398700',
#   'previous_close': '28.860000',
#   'adjusted_previous_close': '28.860000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'RDS.B',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/2931075b-34e5-4fa3-9a4d-78e2ea768243/'},
#  {'ask_price': '0.560000',
#   'ask_size': 1000,
#   'bid_price': '0.543500',
#   'bid_size': 1000,
#   'last_trade_price': '0.552600',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '0.543100',
#   'adjusted_previous_close': '0.541000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'ZNOG',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:59:03Z',
#   'instrument': 'https://api.robinhood.com/instruments/0bae9747-cf93-424b-9009-5fe041676425/'},
#  {'ask_price': '44.000000',
#   'ask_size': 100,
#   'bid_price': '31.750000',
#   'bid_size': 20,
#   'last_trade_price': '32.660000',
#   'last_extended_hours_trade_price': '32.210000',
#   'previous_close': '32.370000',
#   'adjusted_previous_close': '32.370000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'NOVA',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/51ef3cd4-78fd-4f77-b3b3-24a2028d6bc7/'},
#  {'ask_price': '45.000000',
#   'ask_size': 5,
#   'bid_price': '34.550000',
#   'bid_size': 100,
#   'last_trade_price': '35.360000',
#   'last_extended_hours_trade_price': '35.230000',
#   'previous_close': '34.010000',
#   'adjusted_previous_close': '34.010000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'COP',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/eec35cc8-10ba-4596-9ce8-fb83600d30fd/'},
#  {'ask_price': '385.000000',
#   'ask_size': 30,
#   'bid_price': '366.040000',
#   'bid_size': 4,
#   'last_trade_price': '375.140000',
#   'last_extended_hours_trade_price': '375.140000',
#   'previous_close': '367.890000',
#   'adjusted_previous_close': '367.890000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'LMT',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/fbfbfb83-373a-4601-8094-6179a2a1942c/'},
#  {'ask_price': '78.000000',
#   'ask_size': 5,
#   'bid_price': '73.640000',
#   'bid_size': 70,
#   'last_trade_price': '73.640000',
#   'last_extended_hours_trade_price': '73.550000',
#   'previous_close': '73.680000',
#   'adjusted_previous_close': '73.680000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'TAN',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/b36b2cef-34ff-4064-9063-ef140d895239/'},
#  {'ask_price': '7.110000',
#   'ask_size': 200,
#   'bid_price': '4.000000',
#   'bid_size': 25,
#   'last_trade_price': '6.810000',
#   'last_extended_hours_trade_price': '6.810000',
#   'previous_close': '6.490000',
#   'adjusted_previous_close': '6.490000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'SSL',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/e8af3c41-dd6e-4438-bb13-51c3f5dcbbb6/'},
#  {'ask_price': '236.040000',
#   'ask_size': 1,
#   'bid_price': '221.410000',
#   'bid_size': 10,
#   'last_trade_price': '221.600000',
#   'last_extended_hours_trade_price': '222.000000',
#   'previous_close': '227.200000',
#   'adjusted_previous_close': '227.200000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'SEDG',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/b8765f06-0555-45e5-8b05-6819b7e51220/'},
#  {'ask_price': '60.000000',
#   'ask_size': 102,
#   'bid_price': '55.000000',
#   'bid_size': 100,
#   'last_trade_price': '58.760000',
#   'last_extended_hours_trade_price': '58.770000',
#   'previous_close': '54.850000',
#   'adjusted_previous_close': '54.850000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'PSX',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/124133a3-cf48-45f4-a014-934529fdfd7b/'},
#  {'ask_price': '189.670000',
#   'ask_size': 2,
#   'bid_price': '152.970000',
#   'bid_size': 1,
#   'last_trade_price': '171.710000',
#   'last_extended_hours_trade_price': '171.710000',
#   'previous_close': '169.130000',
#   'adjusted_previous_close': '169.130000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'CAT',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/4a4bf458-6a5c-4f74-9c5d-1a4b5b08482e/'},
#  {'ask_price': '84.000000',
#   'ask_size': 1,
#   'bid_price': '79.080000',
#   'bid_size': 50,
#   'last_trade_price': '79.950000',
#   'last_extended_hours_trade_price': '80.010000',
#   'previous_close': '81.400000',
#   'adjusted_previous_close': '81.400000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'FSLR',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/d97168dc-d0f3-464f-bcb9-59a0e1c2526b/'},
#  {'ask_price': '11.000000',
#   'ask_size': 100,
#   'bid_price': '1.650000',
#   'bid_size': 1000,
#   'last_trade_price': '1.690000',
#   'last_extended_hours_trade_price': '1.680000',
#   'previous_close': '1.600000',
#   'adjusted_previous_close': '1.600000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'OPTT',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/df43c301-2419-43f4-b172-736ad80cb112/'},
#  {'ask_price': '51.830000',
#   'ask_size': 50,
#   'bid_price': '49.670000',
#   'bid_size': 2,
#   'last_trade_price': '50.920000',
#   'last_extended_hours_trade_price': '50.990000',
#   'previous_close': '47.280000',
#   'adjusted_previous_close': '47.280000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'VLO',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/2868168f-8ece-49a8-b0e5-4231f0c8716f/'},
#  {'ask_price': '6.800000',
#   'ask_size': 480,
#   'bid_price': '5.700000',
#   'bid_size': 10,
#   'last_trade_price': '5.910000',
#   'last_extended_hours_trade_price': '6.050000',
#   'previous_close': '6.060000',
#   'adjusted_previous_close': '6.060000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'VFF',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/532bfb89-c29a-42a7-89d4-e3c3443b818c/'},
#  {'ask_price': '55.010000',
#   'ask_size': 100,
#   'bid_price': '51.780000',
#   'bid_size': 200,
#   'last_trade_price': '51.970000',
#   'last_extended_hours_trade_price': '51.780000',
#   'previous_close': '51.040000',
#   'adjusted_previous_close': '51.040000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'DOW',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/776d31c1-e278-4476-9d03-9e7125fe946c/'},
#  {'ask_price': '1.740000',
#   'ask_size': 1000,
#   'bid_price': '1.100000',
#   'bid_size': 100,
#   'last_trade_price': '1.740000',
#   'last_extended_hours_trade_price': '1.680000',
#   'previous_close': '1.650000',
#   'adjusted_previous_close': '1.650000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'WTI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/97864505-9698-4fe3-95c1-16564922ca89/'},
#  {'ask_price': '3.190000',
#   'ask_size': 20,
#   'bid_price': '2.510000',
#   'bid_size': 70,
#   'last_trade_price': '3.050000',
#   'last_extended_hours_trade_price': '3.030000',
#   'previous_close': '2.860000',
#   'adjusted_previous_close': '2.860000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'SWN',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/3708482f-e5d3-45a3-ac38-193163a5666d/'},
#  {'ask_price': '18.000000',
#   'ask_size': 100,
#   'bid_price': '15.750000',
#   'bid_size': 4,
#   'last_trade_price': '16.180000',
#   'last_extended_hours_trade_price': '16.200000',
#   'previous_close': '16.020000',
#   'adjusted_previous_close': '16.020000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'BLDP',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/80a5efa2-2872-4937-9307-53aac6eb547d/'},
#  {'ask_price': '0.370000',
#   'ask_size': 10000,
#   'bid_price': '0.218200',
#   'bid_size': 261,
#   'last_trade_price': '0.213200',
#   'last_extended_hours_trade_price': '0.218200',
#   'previous_close': '0.209400',
#   'adjusted_previous_close': '0.209400',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'GTE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/346e1393-96f8-470d-a66a-b8ec1f5775c8/'},
#  {'ask_price': '18.300000',
#   'ask_size': 60,
#   'bid_price': '17.000000',
#   'bid_size': 25,
#   'last_trade_price': '18.050000',
#   'last_extended_hours_trade_price': '18.190000',
#   'previous_close': '17.100000',
#   'adjusted_previous_close': '17.100000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'BE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/82d742b6-84e0-4f22-a3f7-5bfa4afcb8c1/'},
#  {'ask_price': '60.310000',
#   'ask_size': 100,
#   'bid_price': '58.000000',
#   'bid_size': 13,
#   'last_trade_price': '60.310000',
#   'last_extended_hours_trade_price': '60.310000',
#   'previous_close': '59.460000',
#   'adjusted_previous_close': '59.460000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'REGI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/87bbe4c8-bed3-49bb-ba08-ba71f71d0c70/'},
#  {'ask_price': '0.142000',
#   'ask_size': 3,
#   'bid_price': '0.120000',
#   'bid_size': 100,
#   'last_trade_price': '0.129900',
#   'last_extended_hours_trade_price': '0.131000',
#   'previous_close': '0.134000',
#   'adjusted_previous_close': '0.134000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'ENSV',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T23:00:35Z',
#   'instrument': 'https://api.robinhood.com/instruments/4fb622d7-bb98-407e-9952-0a2cb2333466/'},
#  {'ask_price': '31.490000',
#   'ask_size': 860,
#   'bid_price': '1.000000',
#   'bid_size': 1,
#   'last_trade_price': '2.360000',
#   'last_extended_hours_trade_price': '2.350000',
#   'previous_close': '2.180000',
#   'adjusted_previous_close': '2.180000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'SM',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T23:00:33Z',
#   'instrument': 'https://api.robinhood.com/instruments/dc69e730-2138-4ff6-9dc2-34c101295cfb/'},
#  {'ask_price': '4.000000',
#   'ask_size': 4500,
#   'bid_price': '2.530000',
#   'bid_size': 300,
#   'last_trade_price': '3.190000',
#   'last_extended_hours_trade_price': '3.190000',
#   'previous_close': '3.325000',
#   'adjusted_previous_close': '3.325000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'CLNE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/2439c39f-c1ae-4f93-91a8-388c46c13891/'},
#  {'ask_price': '6.800000',
#   'ask_size': 3701,
#   'bid_price': '1.000000',
#   'bid_size': 1,
#   'last_trade_price': '6.150000',
#   'last_extended_hours_trade_price': '6.240000',
#   'previous_close': '3.970000',
#   'adjusted_previous_close': '3.970000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'CBAT',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/522959cb-e3b2-4ffd-99bb-7bfc3808482c/'},
#  {'ask_price': '11.780000',
#   'ask_size': 200,
#   'bid_price': '10.250000',
#   'bid_size': 73,
#   'last_trade_price': '11.780000',
#   'last_extended_hours_trade_price': '11.710000',
#   'previous_close': '11.220000',
#   'adjusted_previous_close': '11.220000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'DVN',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/dc5660e1-36b0-466e-94e1-8cc88ae597eb/'},
#  {'ask_price': '30.300000',
#   'ask_size': 30,
#   'bid_price': '28.310000',
#   'bid_size': 100,
#   'last_trade_price': '28.430000',
#   'last_extended_hours_trade_price': '28.360000',
#   'previous_close': '28.940000',
#   'adjusted_previous_close': '28.940000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'ENB',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/1d228f5e-3d61-44dd-91fb-35e270d5cf56/'},
#  {'ask_price': '69.880000',
#   'ask_size': 200,
#   'bid_price': '26.000000',
#   'bid_size': 1,
#   'last_trade_price': '33.880000',
#   'last_extended_hours_trade_price': '33.840000',
#   'previous_close': '32.690000',
#   'adjusted_previous_close': '32.690000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'XLE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/66be4b8e-c3e5-4490-9fef-37b5cb905756/'},
#  {'ask_price': '8.900000',
#   'ask_size': 100,
#   'bid_price': '7.510000',
#   'bid_size': 19,
#   'last_trade_price': '7.870000',
#   'last_extended_hours_trade_price': '7.950000',
#   'previous_close': '7.730000',
#   'adjusted_previous_close': '7.730000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'SPI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/2c33e6c9-e43d-40a7-8c28-3a219d546d4c/'},
#  {'ask_price': '0.765500',
#   'ask_size': 12857,
#   'bid_price': '0.700000',
#   'bid_size': 579,
#   'last_trade_price': '0.763000',
#   'last_extended_hours_trade_price': '0.760000',
#   'previous_close': '0.699100',
#   'adjusted_previous_close': '0.699100',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'CDEV',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/f174bbb0-3e89-4456-af71-c971d1e6b6eb/'},
#  {'ask_price': '99.500000',
#   'ask_size': 11,
#   'bid_price': '94.400000',
#   'bid_size': 20,
#   'last_trade_price': '94.980000',
#   'last_extended_hours_trade_price': '94.990000',
#   'previous_close': '94.250000',
#   'adjusted_previous_close': '94.250000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'DUK',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/abaf97d3-f256-4246-b540-acc1fccb6fae/'},
#  {'ask_price': '57.940000',
#   'ask_size': 192,
#   'bid_price': '56.140000',
#   'bid_size': 1000,
#   'last_trade_price': '56.160000',
#   'last_extended_hours_trade_price': '56.160000',
#   'previous_close': '54.940000',
#   'adjusted_previous_close': '54.940000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'BX',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/1ec7b3d0-263b-4918-a621-51686af125b2/'},
#  {'ask_price': '0.429000',
#   'ask_size': 2780,
#   'bid_price': '0.230000',
#   'bid_size': 100,
#   'last_trade_price': '0.239000',
#   'last_extended_hours_trade_price': '0.234500',
#   'previous_close': '0.230000',
#   'adjusted_previous_close': '0.230000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'GPOR',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/eef1ac4a-710f-482e-a4c9-eebcd391839c/'},
#  {'ask_price': '50.000000',
#   'ask_size': 175,
#   'bid_price': '18.000000',
#   'bid_size': 30,
#   'last_trade_price': '32.140000',
#   'last_extended_hours_trade_price': '32.200000',
#   'previous_close': '31.190000',
#   'adjusted_previous_close': '31.190000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'NRG',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/fe0a83ed-97b6-48b1-86af-9f10d99e8758/'},
#  {'ask_price': '41.950000',
#   'ask_size': 2,
#   'bid_price': '38.600000',
#   'bid_size': 384,
#   'last_trade_price': '38.830000',
#   'last_extended_hours_trade_price': '38.990000',
#   'previous_close': '39.420000',
#   'adjusted_previous_close': '39.420000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'CSIQ',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/4204795c-da73-4961-9b2c-495fcd13b040/'},
#  {'ask_price': '38.000000',
#   'ask_size': 153,
#   'bid_price': '31.000000',
#   'bid_size': 1000,
#   'last_trade_price': '37.180000',
#   'last_extended_hours_trade_price': '37.180000',
#   'previous_close': '36.010000',
#   'adjusted_previous_close': '36.010000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'BAM',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/96f1ae01-aab3-4750-87f7-17dd7a584960/'},
#  {'ask_price': '8.550000',
#   'ask_size': 200,
#   'bid_price': '8.300000',
#   'bid_size': 100,
#   'last_trade_price': '8.530000',
#   'last_extended_hours_trade_price': '8.530000',
#   'previous_close': '8.280000',
#   'adjusted_previous_close': '8.280000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'PBR',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/223ece33-6e21-4a00-a849-e55252a4451a/'},
#  {'ask_price': '47.480000',
#   'ask_size': 100,
#   'bid_price': '47.000000',
#   'bid_size': 100,
#   'last_trade_price': '47.190000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '47.210000',
#   'adjusted_previous_close': '47.210000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'BYDDY',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:59:03Z',
#   'instrument': 'https://api.robinhood.com/instruments/7907397c-cb8d-452f-8fb3-fb9dc1735cf9/'},
#  {'ask_price': '8.800000',
#   'ask_size': 1000,
#   'bid_price': '8.260000',
#   'bid_size': 3,
#   'last_trade_price': '8.750000',
#   'last_extended_hours_trade_price': '8.770000',
#   'previous_close': '8.390000',
#   'adjusted_previous_close': '8.265000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'MUR',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/d8edff21-cb19-4373-af1c-f83a3c0d01c4/'},
#  {'ask_price': '0.292000',
#   'ask_size': 1000,
#   'bid_price': '0.200000',
#   'bid_size': 1000,
#   'last_trade_price': '0.290000',
#   'last_extended_hours_trade_price': '0.281400',
#   'previous_close': '0.310000',
#   'adjusted_previous_close': '0.310000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'BIOL',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/addefcee-77f1-4c47-ae12-45267197f29f/'},
#  {'ask_price': '8.720000',
#   'ask_size': 1486,
#   'bid_price': '7.050000',
#   'bid_size': 10,
#   'last_trade_price': '8.160000',
#   'last_extended_hours_trade_price': '8.160000',
#   'previous_close': '7.590000',
#   'adjusted_previous_close': '7.590000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'MTDR',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/9c24d6ba-37e9-4407-a338-4ff44d818251/'},
#  {'ask_price': '52.160000',
#   'ask_size': 2,
#   'bid_price': '48.020000',
#   'bid_size': 4,
#   'last_trade_price': '51.010000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '50.220000',
#   'adjusted_previous_close': '50.220000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'BIP',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/188fd09e-c4b6-42e1-a9fe-cbe3714b7f23/'},
#  {'ask_price': '13.980000',
#   'ask_size': 20,
#   'bid_price': '13.110000',
#   'bid_size': 10,
#   'last_trade_price': '13.910000',
#   'last_extended_hours_trade_price': '13.910000',
#   'previous_close': '13.690000',
#   'adjusted_previous_close': '13.690000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'SU',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/b0ae52d3-806c-42ac-9c19-4de89de9720b/'},
#  {'ask_price': '16.200000',
#   'ask_size': 3,
#   'bid_price': '2.370000',
#   'bid_size': 30,
#   'last_trade_price': '14.800000',
#   'last_extended_hours_trade_price': '14.800000',
#   'previous_close': '14.220000',
#   'adjusted_previous_close': '14.220000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'CEQP',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T00:59:59Z',
#   'instrument': 'https://api.robinhood.com/instruments/99ddbcfc-589a-4947-a346-08c23d20806f/'},
#  {'ask_price': '1.350000',
#   'ask_size': 4400,
#   'bid_price': '0.945000',
#   'bid_size': 18,
#   'last_trade_price': '1.060000',
#   'last_extended_hours_trade_price': '1.040000',
#   'previous_close': '1.030000',
#   'adjusted_previous_close': '1.030000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'QEP',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/76b85b5d-1176-4b9b-ba74-72c229ceed50/'},
#  {'ask_price': '0.590000',
#   'ask_size': 5050,
#   'bid_price': '0.375000',
#   'bid_size': 5,
#   'last_trade_price': '0.396600',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '0.385400',
#   'adjusted_previous_close': '0.385400',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'BTE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/1c12e0d8-2c84-4568-8032-e26fae370a40/'},
#  {'ask_price': '29.660000',
#   'ask_size': 12,
#   'bid_price': '18.000000',
#   'bid_size': 10,
#   'last_trade_price': '26.180000',
#   'last_extended_hours_trade_price': '26.180000',
#   'previous_close': '25.410000',
#   'adjusted_previous_close': '25.410000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'SEAS',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/7fa24d4b-fea5-4daf-bcaa-38a28abc3743/'},
#  {'ask_price': '86.300000',
#   'ask_size': 100,
#   'bid_price': '35.000000',
#   'bid_size': 30,
#   'last_trade_price': '84.930000',
#   'last_extended_hours_trade_price': '84.350000',
#   'previous_close': '84.580000',
#   'adjusted_previous_close': '84.580000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'D',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/222a6549-28c1-4f3d-b6c6-73c0d7bde68f/'},
#  {'ask_price': '20.120000',
#   'ask_size': 1,
#   'bid_price': '2.750000',
#   'bid_size': 100,
#   'last_trade_price': '11.370000',
#   'last_extended_hours_trade_price': '11.185000',
#   'previous_close': '10.770000',
#   'adjusted_previous_close': '10.770000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'PE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/9a374f46-9cd4-46ab-a34b-d3d91191e413/'},
#  {'ask_price': '0.006800',
#   'ask_size': 10000,
#   'bid_price': '0.005600',
#   'bid_size': 48250,
#   'last_trade_price': '0.006800',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '0.005700',
#   'adjusted_previous_close': '0.005500',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'LLEXQ',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:17:08Z',
#   'instrument': 'https://api.robinhood.com/instruments/0995b0a9-60ea-4f70-a4b4-cd6209aaa609/'},
#  {'ask_price': '2.130000',
#   'ask_size': 10929,
#   'bid_price': '1.950000',
#   'bid_size': 100,
#   'last_trade_price': '2.140000',
#   'last_extended_hours_trade_price': '2.130000',
#   'previous_close': '2.110000',
#   'adjusted_previous_close': '2.110000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'CIG',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/8308a0cb-b7ae-465a-a97e-f6ecfa5986f6/'},
#  {'ask_price': '4.640000',
#   'ask_size': 100,
#   'bid_price': '4.550000',
#   'bid_size': 100,
#   'last_trade_price': '4.640000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '4.440000',
#   'adjusted_previous_close': '4.430000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'OGZPY',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:32:03Z',
#   'instrument': 'https://api.robinhood.com/instruments/f1a96953-e49b-41b1-af41-c0ff229a03cb/'},
#  {'ask_price': '0.130000',
#   'ask_size': 5000,
#   'bid_price': '0.090000',
#   'bid_size': 20000,
#   'last_trade_price': '0.123700',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '0.121700',
#   'adjusted_previous_close': '0.121000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'ROYTL',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:17:08Z',
#   'instrument': 'https://api.robinhood.com/instruments/bc06bf35-7664-4768-8976-f565c33408db/'},
#  {'ask_price': '17.740000',
#   'ask_size': 4,
#   'bid_price': '3.700000',
#   'bid_size': 20,
#   'last_trade_price': '17.280000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '17.390000',
#   'adjusted_previous_close': '17.060000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'FTAI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T23:00:32Z',
#   'instrument': 'https://api.robinhood.com/instruments/210b0e30-2b7c-4b55-8aa1-fd34721c7d9d/'},
#  {'ask_price': '1.820000',
#   'ask_size': 2000,
#   'bid_price': '1.150000',
#   'bid_size': 1,
#   'last_trade_price': '1.530000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '1.470000',
#   'adjusted_previous_close': '1.470000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'CPG',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T23:00:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/d529e304-464a-4815-b8d3-08a9fc176cd9/'},
#  {'ask_price': '55.490000',
#   'ask_size': 2450,
#   'bid_price': '52.600000',
#   'bid_size': 15,
#   'last_trade_price': '55.130000',
#   'last_extended_hours_trade_price': '55.490000',
#   'previous_close': '55.400000',
#   'adjusted_previous_close': '55.400000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'QCLN',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/bc0e47d9-eb09-4097-88af-10fd22e78fab/'},
#  {'ask_price': '2.500000',
#   'ask_size': 21,
#   'bid_price': '1.810000',
#   'bid_size': 250,
#   'last_trade_price': '2.390000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '2.370000',
#   'adjusted_previous_close': '2.370000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'CIG.C',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T23:00:35Z',
#   'instrument': 'https://api.robinhood.com/instruments/0f36a90a-561d-481e-a745-e55c6a4f9911/'},
#  {'ask_price': '68.210000',
#   'ask_size': 10,
#   'bid_price': '58.500000',
#   'bid_size': 100,
#   'last_trade_price': '61.630000',
#   'last_extended_hours_trade_price': '61.630000',
#   'previous_close': '59.980000',
#   'adjusted_previous_close': '59.980000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'DD',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/fa1afdfc-8091-4dbb-ba85-e559c0c28e14/'},
#  {'ask_price': '30.130000',
#   'ask_size': 43,
#   'bid_price': '24.250000',
#   'bid_size': 1,
#   'last_trade_price': '29.810000',
#   'last_extended_hours_trade_price': '29.830000',
#   'previous_close': '28.890000',
#   'adjusted_previous_close': '28.890000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'PPL',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/58191e01-774b-4a38-ab9c-389793f80e2b/'},
#  {'ask_price': '30.660000',
#   'ask_size': 1480,
#   'bid_price': '24.210000',
#   'bid_size': 8,
#   'last_trade_price': '26.980000',
#   'last_extended_hours_trade_price': '26.980000',
#   'previous_close': '26.540000',
#   'adjusted_previous_close': '26.540000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'SUN',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/4d4bef61-89e9-4562-a5a3-c4fbad62c09b/'},
#  {'ask_price': '6.530000',
#   'ask_size': 5,
# ...
#   'last_extended_hours_trade_price': '25.040000',
#   'previous_close': '25.880000',
#   'adjusted_previous_close': '25.880000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'MMAC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:18Z',
#   'instrument': 'https://api.robinhood.com/instruments/71dbe903-7d1c-4e49-9386-d595998f285a/'},
#  {'ask_price': '74.630000',
#   'ask_size': 200,
#   'bid_price': '72.580000',
#   'bid_size': 500,
#   'last_trade_price': '73.820000',
#   'last_extended_hours_trade_price': '73.820000',
#   'previous_close': '72.290000',
#   'adjusted_previous_close': '72.290000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'ICFI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:01:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/d414ae75-bcac-4b30-bd71-82e4e95c3197/'},
#  {'ask_price': '28.350000',
#   'ask_size': 100,
#   'bid_price': '25.950000',
#   'bid_size': 100,
#   'last_trade_price': '28.940000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '28.940000',
#   'adjusted_previous_close': '28.980000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'APELY',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:44:47Z',
#   'instrument': 'https://api.robinhood.com/instruments/db83d1a9-f8fe-470b-803f-3db769aedde3/'},
#  {'ask_price': '101.020000',
#   'ask_size': 100,
#   'bid_price': '98.980000',
#   'bid_size': 100,
#   'last_trade_price': '100.040000',
#   'last_extended_hours_trade_price': '100.040000',
#   'previous_close': '97.790000',
#   'adjusted_previous_close': '97.790000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'RLI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:14Z',
#   'instrument': 'https://api.robinhood.com/instruments/54248900-b8f9-4fa3-9bb9-6c79e20d73fa/'},
#  {'ask_price': '55.080000',
#   'ask_size': 100,
#   'bid_price': '47.080000',
#   'bid_size': 100,
#   'last_trade_price': '51.680000',
#   'last_extended_hours_trade_price': '51.680000',
#   'previous_close': '49.390000',
#   'adjusted_previous_close': '49.390000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'FLOW',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:11Z',
#   'instrument': 'https://api.robinhood.com/instruments/6343971c-b3ee-4499-82a0-73521da5e5d0/'},
#  {'ask_price': '38.110000',
#   'ask_size': 14,
#   'bid_price': '35.840000',
#   'bid_size': 100,
#   'last_trade_price': '38.020000',
#   'last_extended_hours_trade_price': '38.020000',
#   'previous_close': '37.800000',
#   'adjusted_previous_close': '37.800000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'WLDN',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:19Z',
#   'instrument': 'https://api.robinhood.com/instruments/96b5af12-7c93-4cf6-acb9-cd579d6a2508/'},
#  {'ask_price': '41.890000',
#   'ask_size': 37,
#   'bid_price': '39.280000',
#   'bid_size': 100,
#   'last_trade_price': '41.810000',
#   'last_extended_hours_trade_price': '41.810000',
#   'previous_close': '41.260000',
#   'adjusted_previous_close': '41.260000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'CASS',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:15Z',
#   'instrument': 'https://api.robinhood.com/instruments/8fcf0ad4-faa3-4394-8977-483dbb87768b/'},
#  {'ask_price': '18.500000',
#   'ask_size': 3,
#   'bid_price': '17.000000',
#   'bid_size': 100,
#   'last_trade_price': '18.250000',
#   'last_extended_hours_trade_price': '18.490000',
#   'previous_close': '17.670000',
#   'adjusted_previous_close': '17.670000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'E',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/e760f08c-8b4d-4ade-9aa0-495d70034f02/'},
#  {'ask_price': '6.600000',
#   'ask_size': 5000,
#   'bid_price': '6.460000',
#   'bid_size': 5000,
#   'last_trade_price': '6.510000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '6.270000',
#   'adjusted_previous_close': '6.270000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'FXN',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:04Z',
#   'instrument': 'https://api.robinhood.com/instruments/f7c2fef4-523e-417e-8984-10facf97fd55/'},
#  {'ask_price': '12.340000',
#   'ask_size': 100,
#   'bid_price': '9.000000',
#   'bid_size': 3,
#   'last_trade_price': '10.770200',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '10.520000',
#   'adjusted_previous_close': '10.520000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'MLPI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:03Z',
#   'instrument': 'https://api.robinhood.com/instruments/7d0865c2-ac92-450c-9d5b-87b95b430c2b/'},
#  {'ask_price': '17.000000',
#   'ask_size': 500,
#   'bid_price': '12.670000',
#   'bid_size': 100,
#   'last_trade_price': '15.470000',
#   'last_extended_hours_trade_price': '15.470000',
#   'previous_close': '14.520000',
#   'adjusted_previous_close': '14.520000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'GHM',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:12Z',
#   'instrument': 'https://api.robinhood.com/instruments/2906dd1d-8c25-4523-8474-f9e102986781/'},
#  {'ask_price': '68.000000',
#   'ask_size': 1,
#   'bid_price': '55.490000',
#   'bid_size': 100,
#   'last_trade_price': '59.510000',
#   'last_extended_hours_trade_price': '59.510000',
#   'previous_close': '56.910000',
#   'adjusted_previous_close': '56.910000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'MTX',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:09Z',
#   'instrument': 'https://api.robinhood.com/instruments/2c166dea-89c2-4eec-8804-c20ec2db8ffe/'},
#  {'ask_price': '51.450000',
#   'ask_size': 300,
#   'bid_price': '47.410000',
#   'bid_size': 300,
#   'last_trade_price': '49.383900',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '48.900000',
#   'adjusted_previous_close': '48.900000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'GII',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:15:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/6a42b66b-faa9-4c2a-93d5-d533adf0644d/'},
#  {'ask_price': '29.520000',
#   'ask_size': 100,
#   'bid_price': '25.550000',
#   'bid_size': 100,
#   'last_trade_price': '25.590000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '25.520000',
#   'adjusted_previous_close': '25.520000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'AE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:02Z',
#   'instrument': 'https://api.robinhood.com/instruments/2b7095cd-8643-4955-b84f-2dbd60ac144b/'},
#  {'ask_price': '23.000000',
#   'ask_size': 1,
#   'bid_price': '9.040000',
#   'bid_size': 100,
#   'last_trade_price': '13.370000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '13.090000',
#   'adjusted_previous_close': '13.090000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'ENFR',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T23:00:08Z',
#   'instrument': 'https://api.robinhood.com/instruments/6e2979f5-e9ef-408f-82b7-ac81a80bc0a8/'},
#  {'ask_price': '75.490000',
#   'ask_size': 100,
#   'bid_price': '42.920000',
#   'bid_size': 583,
#   'last_trade_price': '74.740000',
#   'last_extended_hours_trade_price': '74.740000',
#   'previous_close': '72.730000',
#   'adjusted_previous_close': '72.730000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'SXI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:59Z',
#   'instrument': 'https://api.robinhood.com/instruments/27b392c1-4362-4d76-b286-aee84d006e71/'},
#  {'ask_price': '55.000000',
#   'ask_size': 1000,
#   'bid_price': '43.000000',
#   'bid_size': 50,
#   'last_trade_price': '50.790000',
#   'last_extended_hours_trade_price': '50.790000',
#   'previous_close': '50.720000',
#   'adjusted_previous_close': '50.720000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'ATNI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-14T01:00:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/e845fe7d-360a-47a6-a905-ea57f5bcb4a6/'},
#  {'ask_price': '30.300000',
#   'ask_size': 100,
#   'bid_price': '24.500000',
#   'bid_size': 100,
#   'last_trade_price': '27.500000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '26.960000',
#   'adjusted_previous_close': '26.910000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'FRRVY',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:36:49Z',
#   'instrument': 'https://api.robinhood.com/instruments/73a985d1-9b73-499b-87ce-8d40ae1707ec/'},
#  {'ask_price': '9.660000',
#   'ask_size': 2000,
#   'bid_price': '9.470000',
#   'bid_size': 2000,
#   'last_trade_price': '9.530000',
#   'last_extended_hours_trade_price': '9.510000',
#   'previous_close': '9.680100',
#   'adjusted_previous_close': '9.680100',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'DBE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T23:27:25Z',
#   'instrument': 'https://api.robinhood.com/instruments/45342621-999c-441d-8642-1d7445b216e1/'},
#  {'ask_price': '14.000000',
#   'ask_size': 17,
#   'bid_price': '11.660000',
#   'bid_size': 100,
#   'last_trade_price': '12.874300',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '12.339700',
#   'adjusted_previous_close': '12.339700',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'JHME',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:03Z',
#   'instrument': 'https://api.robinhood.com/instruments/f52b7ffa-0f7e-4601-b7d7-a6c4fd5fec3a/'},
#  {'ask_price': '27.970000',
#   'ask_size': 100,
#   'bid_price': '24.530000',
#   'bid_size': 100,
#   'last_trade_price': '25.950000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '24.785000',
#   'adjusted_previous_close': '24.785000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'RYE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:04Z',
#   'instrument': 'https://api.robinhood.com/instruments/1d3da692-77be-4252-be62-798b45392ea9/'},
#  {'ask_price': '104.550000',
#   'ask_size': 100,
#   'bid_price': '63.720000',
#   'bid_size': 100,
#   'last_trade_price': '82.690000',
#   'last_extended_hours_trade_price': '82.690000',
#   'previous_close': '79.180000',
#   'adjusted_previous_close': '79.180000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'REX',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:16Z',
#   'instrument': 'https://api.robinhood.com/instruments/e8d1344b-fb40-4f8b-80ff-65c191c3a888/'},
#  {'ask_price': '5.450000',
#   'ask_size': 3,
#   'bid_price': '5.200000',
#   'bid_size': 1,
#   'last_trade_price': '5.375000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '5.390000',
#   'adjusted_previous_close': '5.390000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'PPIH',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:10Z',
#   'instrument': 'https://api.robinhood.com/instruments/1867f347-f753-4ba1-ac3d-8093aa8c89d8/'},
#  {'ask_price': '14.670000',
#   'ask_size': 2000,
#   'bid_price': '14.440000',
#   'bid_size': 2000,
#   'last_trade_price': '14.535000',
#   'last_extended_hours_trade_price': '14.530000',
#   'previous_close': '13.901900',
#   'adjusted_previous_close': '13.901900',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'PXI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'updated_at': '2020-11-13T21:00:04Z',
#   'instrument': 'https://api.robinhood.com/instruments/39bf6302-8253-429a-b69c-00585c9088b5/'},
#  {'ask_price': '78.470000',
#   'ask_size': 500,
#   'bid_price': '77.920000',
#   'bid_size': 500,
#   'last_trade_price': '78.118800',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '77.073400',
#   'adjusted_previous_close': '77.073400',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'SPXE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:09Z',
#   'instrument': 'https://api.robinhood.com/instruments/091fdd3b-9523-4f19-ae52-2bd44a537f31/'},
#  {'ask_price': '6.880000',
#   'ask_size': 100,
#   'bid_price': '6.110000',
#   'bid_size': 100,
#   'last_trade_price': '6.500000',
#   'last_extended_hours_trade_price': '6.500000',
#   'previous_close': '6.510000',
#   'adjusted_previous_close': '6.510000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'TREC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:25Z',
#   'instrument': 'https://api.robinhood.com/instruments/4655faca-91e3-473f-89c6-02f7ccf326a4/'},
#  {'ask_price': '10.980000',
#   'ask_size': 100,
#   'bid_price': '8.760000',
#   'bid_size': 386,
#   'last_trade_price': '9.470000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '9.290000',
#   'adjusted_previous_close': '9.290000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'TAYD',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:02Z',
#   'instrument': 'https://api.robinhood.com/instruments/25666289-7b30-4a71-b87a-75e7c9864e5d/'},
#  {'ask_price': '58.650000',
#   'ask_size': 4,
#   'bid_price': '55.470000',
#   'bid_size': 3,
#   'last_trade_price': '57.100000',
#   'last_extended_hours_trade_price': '57.100000',
#   'previous_close': '55.600000',
#   'adjusted_previous_close': '55.600000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'PLPC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:18Z',
#   'instrument': 'https://api.robinhood.com/instruments/7defb82f-b8d8-4093-8c60-86edaf3fed2f/'},
#  {'ask_price': '31.000000',
#   'ask_size': 400,
#   'bid_price': '30.600000',
#   'bid_size': 400,
#   'last_trade_price': '30.815400',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '30.130400',
#   'adjusted_previous_close': '30.130400',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'NANR',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:00:05Z',
#   'instrument': 'https://api.robinhood.com/instruments/fb785f78-2919-4c89-8816-a923cb5cbaf3/'},
#  {'ask_price': '9.710000',
#   'ask_size': 100,
#   'bid_price': '7.950000',
#   'bid_size': 130,
#   'last_trade_price': '8.590000',
#   'last_extended_hours_trade_price': None,
#   'previous_close': '8.670000',
#   'adjusted_previous_close': '8.670000',
#   'previous_close_date': '2020-11-12',
#   'symbol': 'CHIE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'updated_at': '2020-11-13T21:15:00Z',
#   'instrument': 'https://api.robinhood.com/instruments/ebeab6c5-283b-4a7a-92e9-ca307890e9da/'}]

# %%
import robin_stocks as r

r.login('lkleinbrodt@gmail.com','RIPmamba24!robinhood')
soi = r.get_all_stocks_from_market_tag('energy')
# Out:
# ERROR: There was an issue loading pickle file. Authentication may be expired - logging in normally.
# Enter Robinhood code for validation:  948666

# %%
energy_tickers = [s['symbol'] for s in soi]

# %%
with open('energy_tickers.txt', 'w') as f:
    f.write('\n'.join(energy_tickers))

# %%
tickers
# Out:
# ['TSLA',
#  'GE',
#  'PLUG',
#  'MRO',
#  'XOM',
#  'FCEL',
#  'KOS',
#  'ET',
#  'BP',
#  'HAL',
#  'OXY',
#  'OASPQ',
#  'RUN',
#  'CEI',
#  'CVX',
#  'PCG',
#  'ENPH',
#  'ICLN',
#  'TELL',
#  'RDS.A',
#  'SPWR',
#  'BRK.A',
#  'APA',
#  'MPC',
#  'HLX',
#  'WPX',
#  'FANG',
#  'NEE',
#  'GEVO',
#  'RDS.B',
#  'ZNOG',
#  'NOVA',
#  'COP',
#  'LMT',
#  'TAN',
#  'SSL',
#  'SEDG',
#  'PSX',
#  'CAT',
#  'FSLR',
#  'OPTT',
#  'VLO',
#  'VFF',
#  'DOW',
#  'WTI',
#  'SWN',
#  'BLDP',
#  'GTE',
#  'BE',
#  'REGI',
#  'ENSV',
#  'SM',
#  'CLNE',
#  'CBAT',
#  'DVN',
#  'ENB',
#  'XLE',
#  'SPI',
#  'CDEV',
#  'DUK',
#  'BX',
#  'GPOR',
#  'NRG',
#  'CSIQ',
#  'BAM',
#  'PBR',
#  'BYDDY',
#  'MUR',
#  'BIOL',
#  'MTDR',
#  'BIP',
#  'SU',
#  'CEQP',
#  'QEP',
#  'BTE',
#  'SEAS',
#  'D',
#  'PE',
#  'LLEXQ',
#  'CIG',
#  'OGZPY',
#  'ROYTL',
#  'FTAI',
#  'CPG',
#  'QCLN',
#  'CIG.C',
#  'DD',
#  'PPL',
#  'SUN',
#  'AR',
#  'GEL',
#  'FE',
#  'FAN',
#  'SO',
#  'AES',
#  'REI',
#  'VNOM',
#  'CVE',
#  'VDE',
#  'BTU',
#  'SIEGY',
#  'HASI',
#  'ERF',
#  'PBF',
#  'GLNCY',
#  'VET',
#  'NGL',
#  'EOG',
#  'PERS',
#  'XOGAQ',
#  'WY',
#  'FLR',
#  'COG',
#  'TAT',
#  'EXC',
#  'ARLP',
#  'SNPS',
#  'PBW',
#  'PXD',
#  'CNP',
#  'AZRE',
#  'DQ',
#  'UEC',
#  'BKEP',
#  'CNQ',
#  'CLR',
#  'TPIC',
#  'UUUU',
#  'WMB',
#  'NEP',
#  'AMPY',
#  'TRGP',
#  'RRC',
#  'LUNA',
#  'FTI',
#  'CKHUY',
#  'KKR',
#  'MCF',
#  'TRCH',
#  'OII',
#  'CRK',
#  'SNMP',
#  'ED',
#  'CVA',
#  'CSX',
#  'YGYI',
#  'URG',
#  'PVL',
#  'KYN',
#  'ACES',
#  'TUSK',
#  'AY',
#  'PED',
#  'WES',
#  'TALO',
#  'EIX',
#  'MNST',
#  'LNG',
#  'NINE',
#  'IEP',
#  'VTNR',
#  'PVAC',
#  'NHYDY',
#  'AMRC',
#  'LONEQ',
#  'GPRE',
#  'MTZ',
#  'XEL',
#  'BLL',
#  'PBFX',
#  'ETN',
#  'KEYS',
#  'RIO',
#  'JCI',
#  'TRP',
#  'CPST',
#  'FSI',
#  'EQT',
#  'OESX',
#  'PBR.A',
#  'BG',
#  'CHKR',
#  'PTEN',
#  'SBR',
#  'CWEN',
#  'PDCE',
#  'MEGEF',
#  'ECL',
#  'CPYYY',
#  'MGY',
#  'AVAV',
#  'CNX',
#  'RSG',
#  'VST',
#  'SNDE',
#  'CPSH',
#  'CXO',
#  'JBL',
#  'EQNR',
#  'NILSY',
#  'IEA',
#  'FENY',
#  'HTHIY',
#  'ESTE',
#  'NXE',
#  'TAC',
#  'BHP',
#  'NS',
#  'XONE',
#  'CORR',
#  'EGY',
#  'ATI',
#  'AMKBY',
#  'FMC',
#  'NFE',
#  'PAGP',
#  'GWW',
#  'HES',
#  'SRE',
#  'BRN',
#  'EMN',
#  'ENG',
#  'IFNNY',
#  'DTE',
#  'DOV',
#  'CLIR',
#  'CRT',
#  'ITOCY',
#  'GVA',
#  'PEG',
#  'AGRO',
#  'MRC',
#  'VREX',
#  'NVGS',
#  'CSWC',
#  'HNRG',
#  'TGC',
#  'SJT',
#  'BSM',
#  'IMO',
#  'CVIAQ',
#  'CQP',
#  'XYL',
#  'AMSC',
#  'FPL',
#  'SWRAY',
#  'ACSAY',
#  'HCHC',
#  'EC',
#  'SXC',
#  'GBR',
#  'UGI',
#  'HFC',
#  'DK',
#  'NVEE',
#  'CCEP',
#  'USDP',
#  'BW',
#  'MIC',
#  'ECTM',
#  'IXC',
#  'BWEN',
#  'WTTR',
#  'TGA',
#  'SD',
#  'FTS',
#  'ROP',
#  'METC',
#  'XEC',
#  'FLMN',
#  'DNOW',
#  'LUKOY',
#  'TANH',
#  'NESR',
#  'TENB',
#  'CCR',
#  'VOC',
#  'UGP',
#  'OISHY',
#  'BRY',
#  'INT',
#  'FLNG',
#  'ETR',
#  'CZZ',
#  'PFIE',
#  'MXIM',
#  'CVI',
#  'ACLS',
#  'PBD',
#  'SPKE',
#  'ACH',
#  'MIELY',
#  'YUMAQ',
#  'YLCO',
#  'SSUMY',
#  'HEP',
#  'ASPN',
#  'ORA',
#  'OC',
#  'DLNG',
#  'ES',
#  'SNP',
#  'VIST',
#  'EONGY',
#  'NI',
#  'ATO',
#  'EPM',
#  'VSH',
#  'HCC',
#  'UMICY',
#  'GTLS',
#  'PSN',
#  'MDU',
#  'PRT',
#  'INFO',
#  'ALYA',
#  'GDV',
#  'CTRA',
#  'BKH',
#  'MARPS',
#  'WEC',
#  'CEO',
#  'ENIA',
#  'MITSY',
#  'CASY',
#  'CIR',
#  'BBL',
#  'RAVN',
#  'PW',
#  'ERII',
#  'CELP',
#  'JAN',
#  'HE',
#  'PLSE',
#  'CUTR',
#  'PARR',
#  'NFG',
#  'LNT',
#  'PTR',
#  'GRBK',
#  'MTR',
#  'AVA',
#  'VCRA',
#  'PSCE',
#  'RJN',
#  'CEIX',
#  'MG',
#  'SMOG',
#  'GNE',
#  'YPF',
#  'TX',
#  'MXC',
#  'HGKGY',
#  'AJG',
#  'GZPFY',
#  'LEU',
#  'HIL',
#  'TDY',
#  'BOOM',
#  'ACA',
#  'OGE',
#  'SOUHY',
#  'CLH',
#  'IYE',
#  'PNW',
#  'UNVR',
#  'TEX',
#  'CLS',
#  'III',
#  'OBELF',
#  'TDW',
#  'CSUAY',
#  'VRSK',
#  'TS',
#  'FEI',
#  'OSG',
#  'CCU',
#  'NRT',
#  'ALE',
#  'SRTS',
#  'CMS',
#  'DMLP',
#  'SGOC',
#  'GASS',
#  'CWEN.A',
#  'KMF',
#  'ITRI',
#  'SWX',
#  'SJI',
#  'CECE',
#  'IDA',
#  'RWEOY',
#  'UUGRY',
#  'TGEN',
#  'BCEI',
#  'ITT',
#  'AEIS',
#  'LMB',
#  'TGS',
#  'BRKR',
#  'PAM',
#  'NJR',
#  'BGR',
#  'GDP',
#  'AGR',
#  'ROCK',
#  'SPLP',
#  'CYAN',
#  'CLWT',
#  'ORKLY',
#  'PEYUF',
#  'AGX',
#  'ERY',
#  'OTTR',
#  'ALEX',
#  'TTDKY',
#  'TOT',
#  'FUL',
#  'SYNE',
#  'AAON',
#  'GPRK',
#  'APYX',
#  'ELP',
#  'WOPEY',
#  'SR',
#  'ULBI',
#  'CPK',
#  'DPG',
#  'MGEE',
#  'NRP',
#  'SBOW',
#  'ENS',
#  'PWCDF',
#  'ARGO',
#  'SGTPY',
#  'LDL',
#  'KMT',
#  'GYLD',
#  'BVN',
#  'VMI',
#  'TBI',
#  'RNGR',
#  'SSEZY',
#  'PROS',
#  'ASH',
#  'AEGN',
#  'GLPEY',
#  'AZZ',
#  'GRID',
#  'SOMMY',
#  'STN',
#  'ESI',
#  'NLR',
#  'SIF',
#  'NX',
#  'EPSN',
#  'EMLP',
#  'COMT',
#  'HWKN',
#  'GIFI',
#  'GUNR',
#  'ASTE',
#  'RBC',
#  'ITGR',
#  'FSTR',
#  'ELLO',
#  'ESE',
#  'PXE',
#  'IX',
#  'FILL',
#  'MMAC',
#  'ICFI',
#  'APELY',
#  'RLI',
#  'FLOW',
#  'WLDN',
#  'CASS',
#  'E',
#  'FXN',
#  'MLPI',
#  'GHM',
#  'MTX',
#  'GII',
#  'AE',
#  'ENFR',
#  'SXI',
#  'ATNI',
#  'FRRVY',
#  'DBE',
#  'JHME',
#  'RYE',
#  'REX',
#  'PPIH',
#  'PXI',
#  'SPXE',
#  'TREC',
#  'TAYD',
#  'PLPC',
#  'NANR',
#  'CHIE']

# %%
class Backtester():
    def __init__(self, trading_strategy, execution_strategy):
        self.trader = trading_strategy
        self.executor = execution_strategy
    
    def one_day(date):
        assert isinstance(date, pd.Timestamp)
        
        #Check market open
        day_ts = pd.Timestamp(day, tz = 'America/New_York')
        calendar = api.get_calendar(start = day_ts.isoformat(), end = (day_ts + relativedelta(days = 1)).isoformat())
        if calendar[0].date != day:
            print('Skipping {}, the market is closed.'.format(day.strftime('%Y-%m-%d')))
            return None, None, None
        
        
    def run(start_date, end_date):
